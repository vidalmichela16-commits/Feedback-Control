# %% [markdown]
# Abellanosa, John Harvey R.
# CPE3A
# Activity #3 Poles and Zeroes

# %%
import control

# %%
import control as ctrl
import matplotlib.pyplot as plt

num = [10, 20] # Numerator: 10s + 20
den = [1, 15, 50, 0] # Denominator: s^3 + 15s^2 + 50s + 0

G = ctrl.tf(num, den)
print(G)
# Out:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#        10 s + 20
#   -------------------
#   s^3 + 15 s^2 + 50 s

# %% [markdown]
# Poles are the roots of the denominator

# %%
poles = ctrl.poles(G)
print("Poles:", poles)
# Out:
# Poles: [-10.+0.j  -5.+0.j   0.+0.j]

# %% [markdown]
# Zeros are the roots of the numerator

# %%
zeros = ctrl.zeros(G)
print("Zeros:", zeros)
# Out:
# Zeros: [-2.+0.j]

# %%
ctrl.pzmap(G, grid=True,)
plt.show()
